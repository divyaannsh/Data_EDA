# %%
#data visulaization

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\n k shreevatav\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
x =[1,2,3,4,5,6,7]
y=[1,2,3,4,5,6,7]

plt.plot(x,y)
plt.xlabel('X axis')
plt.title('basic line plot')
# Out:
# Text(0.5, 1.0, 'basic line plot')

# %%
#multiple plots
##sub plot

# %%
x =[1,2,3,4,5,6,7]
y1=[1,2,3,4,5,6,7]
y2 =[1,2,3,4,5,6,7]


plt.figure(figsize=(9,5))

plt.subplot(1,2,1)

plt.plot(x,y1,color='green')
plt.title("plot 1")
# Out:
# Text(0.5, 1.0, 'plot 1')

# %%
import matplotlib.pyplot as plt

# Corrected data
cat = ['a', 'c', 'd', 'f']
values = [5, 7, 3, 8]

# Create bar plot
plt.bar(cat, values, color='purple')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot Example')
plt.show()

# %%
#histogram
data=[1,2,3,4,5,6,7,8,9]

plt.hist(data,bins=5)
# Out:
# (array([2., 2., 1., 2., 2.]),
#  array([1. , 2.6, 4.2, 5.8, 7.4, 9. ]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['a', 'b', 'c', 'd']
sizes = [30, 20, 40, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.2, 0, 0, 0)  # Explode the first slice

# Create pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)

plt.title('Pie Chart Example')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()
